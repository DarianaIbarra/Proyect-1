# %%
#### Now since this is a new file we need to import other modules (YAY!) including our R' emulator
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

### and let's not forget the usual gang:
import pandas as pd
import numpy as np
import matplotlib as plt
import re
import os

# %%
#### Before we get started in an R' environment. We need to talk about something important.
#### Rentrez does not use SNP ID to search. It uses UID. As in, they don't use 'rs2000' 
#### but rather '2000'. So we need to use our previous output and split the function.
Output_GeneSNP_file = pd.read_csv('Resources/OutputFromExtractionCode/Editable_Gene_And_dbSNP_ID_Merged.csv')
Output_GeneSNP_file.head(10)

output_path = 'Resources/OutputFromExtractionCode'

# %%
### Now we split it. 
Split_dbSNP_ID = Output_GeneSNP_file
Split_dbSNP_ID[['rs', 'UID']] = Output_GeneSNP_file['SNP ID'].str.split('rs', expand = True)
Split_dbSNP_ID.head(10)

#And delete the rs column:
UID_SNP = Split_dbSNP_ID.drop(columns=['rs'])
UID_SNP.head(10)

## Now we have the UID
# Out:
#                  GENE      SNP ID       UID
# 0          CDKN2B-AS1   rs4977574   4977574
# 1                 LPA  rs10455872  10455872
# 2              ZNF335   rs3827066   3827066
# 3              CELSR2  rs12740374  12740374
# 4  LINC00540 - FTH1P7   rs7994761   7994761
# 5                APOE    rs429358    429358
# 6             SMARCA4  rs73015011  73015011
# 7             ADAMTS8   rs4936098   4936098
# 8              CHRNA5  rs17486278  17486278
# 9          CDKN2B-AS1   rs2891168   2891168

# %%
### Let's import RENTREZ to our python environment
rentrez = importr('rentrez')

### You'll need to provide an email address to use Entrez tools. BTW Hot tip: 
### If you have multiple lines, using triple quotes is cleaner and easier to read:

robjects.r('''
library(rentrez)
entrez_email <- "kenji.ponsm@gmail.com"
''')

# %%
## Let's give it a test shall we? Let's say I want the information of rs429358 (GENE: APOE)
print(UID_SNP.iloc[0,2])
test_snp = UID_SNP.iloc[0,2]
search_test = rentrez.entrez_summary(db='snp', id=test_snp)
search_test_dict = {key: str(search_test.rx2(key) [0]) for key in search_test.names}

search_test_df = pd.DataFrame([search_test_dict])

search_test_df.head(10)
# Out:
# 4977574
#        uid   snp_id allele_origin  \
# 0  4977574  4977574
#
#                                          global_mafs global_population  \
# 0   [1] "1000Genomes"    "ALSPAC"         "Chilea...
#
#   global_samplesize suspected clinical_significance               genes  \
# 0                                       risk-factor  [1] "CDKN2B-AS1"\n
#
#             acc  ... allele snp_class      chrpos chrpos_prev_assm text  \
# 0  NC_000009.12  ...      D       snv  9:22098575       9:22098574
#
#   snp_id_sort clinical_sort cited_sort chrpos_sort merged_sort
# 0  0004977574             1             0022098575           0
#
# [1 rows x 32 columns]

# %%
print(search_test.names)
# Out:
#  [1] "uid"                   "snp_id"                "allele_origin"
#  [4] "global_mafs"           "global_population"     "global_samplesize"
#  [7] "suspected"             "clinical_significance" "genes"
# [10] "acc"                   "chr"                   "handle"
# [13] "spdi"                  "fxn_class"             "validated"
# [16] "docsum"                "tax_id"                "orig_build"
# [19] "upd_build"             "createdate"            "updatedate"
# [22] "ss"                    "allele"                "snp_class"
# [25] "chrpos"                "chrpos_prev_assm"      "text"
# [28] "snp_id_sort"           "clinical_sort"         "cited_sort"
# [31] "chrpos_sort"           "merged_sort"

# %%
### And let's filter for the actual values we want to extract: 
desired_dbSNP_values = (['genes', 'snp_id', 'uid', 'snp_class', 
                         'fxn_class', 'chr', 'chrpos', 'global_population', 
                         'allele','clinical_significance', 'acc'] 
                         )
filtered_search_test_dict = {key: str(search_test.rx2(key)[0]) for key in search_test.names if key in desired_dbSNP_values}
filtered_search_test = pd.DataFrame([filtered_search_test_dict])
filtered_search_test
# Out:
#        uid   snp_id global_population clinical_significance  \
# 0  4977574  4977574                             risk-factor
#
#                 genes           acc chr  \
# 0  [1] "CDKN2B-AS1"\n  NC_000009.12   9
#
#                                            fxn_class allele snp_class  \
# 0  genic_downstream_transcript_variant,intron_var...      D       snv
#
#        chrpos
# 0  9:22098575

# %%
filtered_and_ordered_search_test = filtered_search_test[[col for col in desired_dbSNP_values if col in filtered_search_test.columns]]
filtered_and_ordered_search_test
# Out:
#                 genes   snp_id      uid snp_class  \
# 0  [1] "CDKN2B-AS1"\n  4977574  4977574       snv
#
#                                            fxn_class chr      chrpos  \
# 0  genic_downstream_transcript_variant,intron_var...   9  9:22098575
#
#   global_population allele clinical_significance           acc
# 0                        D           risk-factor  NC_000009.12

# %%
all_snp_data = []

# Open a text file in write mode to log skipped rows
with open("skipped_rows_log.txt", "w") as log_file:
    log_file.write("Details of rows skipped due to None UID:\n\n")

    for index, row in UID_SNP.iterrows():
        test_snp = row['UID']
        
        # Check if the UID is not None
        if test_snp is None:
            # Print to console and write to log file
            log_message = f"Skipping row {index} because UID is None. Row details:\n{row}\n\n"
            print(log_message)
            log_file.write(log_message)
            continue  # Skip this iteration if UID is None

        try: 
            # Retrieve SNP data from the SNP database
            search_test = rentrez.entrez_summary(db='snp', id=test_snp)
            
            # Filter and safely retrieve desired fields
            filtered_search_test_dict = {
                key: str(search_test.rx2(key)[0]) if len(search_test.rx2(key)) > 0 else None
                for key in search_test.names if key in desired_dbSNP_values
            }
            
            # Order the data to match the desired column order
            ordered_data = {key: filtered_search_test_dict.get(key, None) for key in desired_dbSNP_values}
            
            # Append ordered data to the results list
            all_snp_data.append(ordered_data)

        except Exception as e:
            error_message = f"Error retrieving data for UID {test_snp}: {e}\n"
            print(error_message)
            log_file.write(error_message)

# Convert results to DataFrame
final_df = pd.DataFrame(all_snp_data)

# Display the first 10 rows
final_df.head(50)
# Out:
# Skipping row 53 because UID is None. Row details:
# GENE                 NaN
# SNP ID    chr6:112398675
# UID                 None
# Name: 53, dtype: object
#
#
# Skipping row 116 because UID is None. Row details:
# GENE                NaN
# SNP ID    chr2:20679060
# UID                None
# Name: 116, dtype: object
#
#
# Skipping row 140 because UID is None. Row details:
# GENE                  NaN
# SNP ID    chr11:130410772
# UID                  None
# Name: 140, dtype: object
#                                   genes     snp_id        uid snp_class  \
# 0                    [1] "CDKN2B-AS1"\n    4977574    4977574       snv
# 1                           [1] "LPA"\n   10455872   10455872       snv
# 2                        [1] "ZNF335"\n    3827066    3827066       snv
# 3                        [1] "CELSR2"\n   12740374   12740374       snv
# 4                                  None    7994761    7994761       snv
# 5                          [1] "APOE"\n     429358     429358       snv
# 6                                  None   73015011   73015011       snv
# 7                       [1] "ADAMTS8"\n    4936098    4936098       snv
# 8                        [1] "CHRNA5"\n   17486278   17486278       snv
# 9                    [1] "CDKN2B-AS1"\n    2891168    2891168       snv
# 10                          [1] "LPA"\n  140570886  140570886       snv
# 11                   [1] "CDKN2B-AS1"\n   10757274   10757274       snv
# 12                                 None     434182     434182       snv
# 13                         [1] "ZPR1"\n     964184     964184       snv
# 14                       [1] "DAB2IP"\n    7025486    7025486       snv
# 15                        [1] "PLCE1"\n     731141     731141       snv
# 16                         [1] "IL6R"\n   12126142   12126142       snv
# 17                         [1] "LRP1"\n   11172113   11172113       snv
# 18                        [1] "SUGCT"\n   17688414   17688414       snv
# 19                         [1] "GDF7"\n    9306894    9306894       snv
# 20                                 None    1660364    1660364       snv
# 21                                 None    1892971    1892971       snv
# 22                                 None   77925345   77925345       snv
# 23                          [1] "LPA"\n   10455872   10455872       snv
# 24                          [1] "ERG"\n    2836411    2836411       snv
# 25                                 None    2954021    2954021       snv
# 26                         [1] "ZPR1"\n     964184     964184       snv
# 27                          [1] "LPL"\n        331        331       snv
# 28                         [1] "LIPA"\n    1412444    1412444       snv
# 29                       [1] "CELSR2"\n   12740374   12740374       snv
# 30                          [1] "LPA"\n  118039278  118039278       snv
# 31                        [1] "PLCE1"\n   11187851   11187851       snv
# 32                        [1] "PLAUR"\n       4760       4760       snv
# 33                        [1] "PCIF1"\n   58749629   58749629       snv
# 34                                 None    7240701    7240701       snv
# 35                                 None     247617     247617       snv
# 36                                 None  143235478  143235478    delins
# 37                                 None    6734238    6734238       snv
# 38                         [1] "VMP1"\n    2150879    2150879       snv
# 39                                 None   17368814   17368814       snv
# 40                      [1] "ADAMTS8"\n    4936098    4936098       snv
# 41                        [1] "PCSK9"\n   11591147   11591147       snv
# 42                                 None   12408895   12408895       snv
# 43                        [1] "LTBP4"\n   34093919   34093919       snv
# 44                         [1] "APOE"\n     429358     429358       snv
# 45                        [1] "SUGCT"\n   79486579   79486579       snv
# 46  [1] "LOC105378327" "LOC124902436"\n   12768538   12768538       snv
# 47                         [1] "DNM3"\n    2227200    2227200       snv
# 48                 [1] "LOC124904262"\n    4401144    4401144       snv
# 49                    [1] "LINC02732"\n   10891091   10891091       snv
#
#                                             fxn_class chr        chrpos  \
# 0   genic_downstream_transcript_variant,intron_var...   9    9:22098575
# 1                                      intron_variant   6   6:160589086
# 2   downstream_transcript_variant,intron_variant,g...  20   20:45957384
# 3                                 3_prime_UTR_variant   1   1:109274968
# 4                                                      13   13:22297307
# 5            missense_variant,coding_sequence_variant  19   19:44908684
# 6                                                      19   19:11079088
# 7                                      intron_variant  11  11:130410772
# 8                                      intron_variant  15   15:78575140
# 9   genic_downstream_transcript_variant,intron_var...   9    9:22098620
# 10                                     intron_variant   6   6:160591981
# 11  intron_variant,genic_downstream_transcript_var...   9    9:22096056
# 12                                                     18   18:22702893
# 13  3_prime_UTR_variant,genic_downstream_transcrip...  11  11:116778201
# 14   intron_variant,genic_upstream_transcript_variant   9   9:121660124
# 15                                     intron_variant  10   10:94138924
# 16  genic_downstream_transcript_variant,intron_var...   1   1:154452980
# 17                                     intron_variant  12   12:57133500
# 18  intron_variant,genic_downstream_transcript_var...   7    7:40801371
# 19                                3_prime_UTR_variant   2    2:20678345
# 20                                                      1   1:214232262
# 21                                                     11  11:102924877
# 22                                                     12   12:19777560
# 23                                     intron_variant   6   6:160589086
# 24  genic_downstream_transcript_variant,intron_var...  21   21:38447907
# 25                                                      8   8:125469835
# 26  3_prime_UTR_variant,genic_downstream_transcrip...  11  11:116778201
# 27                                     intron_variant   8    8:19962894
# 28                                     intron_variant  10   10:89243170
# 29                                3_prime_UTR_variant   1   1:109274968
# 30                                     intron_variant   6   6:160564494
# 31  genic_downstream_transcript_variant,intron_var...  10   10:94310118
# 32  coding_sequence_variant,genic_downstream_trans...  19   19:43648948
# 33  intron_variant,upstream_transcript_variant,gen...  20   20:45942678
# 34                                                     18   18:22523104
# 35                                                     16   16:56956804
# 36                                                     20   20:45927137
# 37                                                      2   2:113083453
# 38                                     intron_variant  17   17:59781849
# 39                                                     11  11:102877965
# 40                                     intron_variant  11  11:130410772
# 41  upstream_transcript_variant,coding_sequence_va...   1    1:55039974
# 42                                                      1     1:9378116
# 43           coding_sequence_variant,missense_variant  19   19:40611394
# 44           missense_variant,coding_sequence_variant  19   19:44908684
# 45  genic_downstream_transcript_variant,intron_var...   7    7:40391533
# 46   intron_variant,genic_upstream_transcript_variant  10   10:62646598
# 47  genic_downstream_transcript_variant,intron_var...   1   1:172364308
# 48                      non_coding_transcript_variant  18   18:22613705
# 49                                     intron_variant  11  11:110358805
#
#    global_population allele  \
# 0                         D
# 1                         R
# 2                         Y
# 3                         K
# 4                         D
# 5                         Y
# 6                         Y
# 7                         D
# 8                         M
# 9                         R
# 10                        Y
# 11                        N
# 12                        N
# 13                        S
# 14                        R
# 15                        R
# 16                        V
# 17                        B
# 18                        B
# 19                        R
# 20                        H
# 21                        R
# 22                        R
# 23                        R
# 24                        H
# 25                        R
# 26                        S
# 27                        R
# 28                        B
# 29                        K
# 30                        R
# 31                        D
# 32                        R
# 33                        D
# 34                        Y
# 35                        M
# 36                        N
# 37                        R
# 38                        R
# 39                        R
# 40                        D
# 41                        D
# 42                        N
# 43                        R
# 44                        Y
# 45                        V
# 46                        S
# 47                        R
# 48                        Y
# 49                        N
#
#                                 clinical_significance           acc
# 0                                         risk-factor  NC_000009.12
# 1                                              benign  NC_000006.12
# 2                                              benign  NC_000020.11
# 3                                         association  NC_000001.11
# 4                                                      NC_000013.11
# 5   pathogenic,risk-factor,association,conflicting...  NC_000019.10
# 6                                                      NC_000019.10
# 7                                                      NC_000011.10
# 8                                                      NC_000015.10
# 9                                                      NC_000009.12
# 10                                                     NC_000006.12
# 11                                        risk-factor  NC_000009.12
# 12                                                     NC_000018.10
# 13                                                     NC_000011.10
# 14                                                     NC_000009.12
# 15                                                     NC_000010.11
# 16                                                     NC_000001.11
# 17                                                     NC_000012.12
# 18                                                     NC_000007.14
# 19                                                     NC_000002.12
# 20                                                     NC_000001.11
# 21                                                     NC_000011.10
# 22                                                     NC_000012.12
# 23                                             benign  NC_000006.12
# 24                                                      NC_000021.9
# 25                                                     NC_000008.11
# 26                                                     NC_000011.10
# 27                                                     NC_000008.11
# 28                                                     NC_000010.11
# 29                                        association  NC_000001.11
# 30                                                     NC_000006.12
# 31                                                     NC_000010.11
# 32                                                     NC_000019.10
# 33                                                     NC_000020.11
# 34                                                     NC_000018.10
# 35                                                     NC_000016.10
# 36                                                     NC_000020.11
# 37                                                     NC_000002.12
# 38                                                     NC_000017.11
# 39                                                     NC_000011.10
# 40                                                     NC_000011.10
# 41                                                     NC_000001.11
# 42                                                     NC_000001.11
# 43                        benign,benign-likely-benign  NC_000019.10
# 44  pathogenic,risk-factor,association,conflicting...  NC_000019.10
# 45                                                     NC_000007.14
# 46                                                     NC_000010.11
# 47                                                     NC_000001.11
# 48                                                     NC_000018.10
# 49                                                     NC_000011.10

# %%
#### Now let's make a copy of our RAW results:
final_df.to_csv(os.path.join(output_path, 'compiled_SNPs_RENTREZ_RAW.csv'), index=False)

# %%
#### And let's make it beautiful by rearranging and sorting each column:
#### First, let's delete all variants that are not SNVs:
filtered_final_df = final_df.loc[final_df['snp_class'] == 'snv'] 
filtered_final_df
# Out:
#                                  genes     snp_id        uid snp_class  \
# 0                   [1] "CDKN2B-AS1"\n    4977574    4977574       snv
# 1                          [1] "LPA"\n   10455872   10455872       snv
# 2                       [1] "ZNF335"\n    3827066    3827066       snv
# 3                       [1] "CELSR2"\n   12740374   12740374       snv
# 4                                 None    7994761    7994761       snv
# ..                                 ...        ...        ...       ...
# 145                    [1] "C5orf67"\n     464605     464605       snv
# 146  [1] "ANKRD44"     "ANKRD44-IT1"\n     919433     919433       snv
# 147                               None  530948381  530948381       snv
# 148                      [1] "MON1A"\n  142344547  142344547       snv
# 149                               None  141830649  141830649       snv
#
#                                              fxn_class chr       chrpos  \
# 0    genic_downstream_transcript_variant,intron_var...   9   9:22098575
# 1                                       intron_variant   6  6:160589086
# 2    downstream_transcript_variant,intron_variant,g...  20  20:45957384
# 3                                  3_prime_UTR_variant   1  1:109274968
# 4                                                       13  13:22297307
# ..                                                 ...  ..          ...
# 145                      non_coding_transcript_variant   5   5:56511543
# 146   genic_upstream_transcript_variant,intron_variant   2  2:197301841
# 147                                                     22  22:25507825
# 148                                     intron_variant   3   3:49918603
# 149                                                     14  14:20526739
#
#     global_population allele clinical_significance           acc
# 0                          D           risk-factor  NC_000009.12
# 1                          R                benign  NC_000006.12
# 2                          Y                benign  NC_000020.11
# 3                          K           association  NC_000001.11
# 4                          D                        NC_000013.11
# ..                ...    ...                   ...           ...
# 145                        H                        NC_000005.10
# 146                        V                        NC_000002.12
# 147                        R                        NC_000022.11
# 148                        R                        NC_000003.12
# 149                        W                         NC_000014.9
#
# [147 rows x 11 columns]

# %%
### Now let's clean up la mugre of each cell in the genes column

# Define a function to clean up each cell
def clean_cell(value):
    if isinstance(value, str):
        # Remove `[1]`, quotation marks, and newline characters
        cleaned_value = re.sub(r'^\[\d+\]\s*"', '', value).replace('"', '').strip()
        return cleaned_value
    return value

# Apply the cleaning function to the 'genes' column using .loc
filtered_final_df.loc[:, 'genes'] = filtered_final_df['genes'].apply(clean_cell)

filtered_final_df.head(200)
# Out:
#                        genes     snp_id        uid snp_class  \
# 0                 CDKN2B-AS1    4977574    4977574       snv
# 1                        LPA   10455872   10455872       snv
# 2                     ZNF335    3827066    3827066       snv
# 3                     CELSR2   12740374   12740374       snv
# 4                       None    7994761    7994761       snv
# ..                       ...        ...        ...       ...
# 145                  C5orf67     464605     464605       snv
# 146  ANKRD44     ANKRD44-IT1     919433     919433       snv
# 147                     None  530948381  530948381       snv
# 148                    MON1A  142344547  142344547       snv
# 149                     None  141830649  141830649       snv
#
#                                              fxn_class chr       chrpos  \
# 0    genic_downstream_transcript_variant,intron_var...   9   9:22098575
# 1                                       intron_variant   6  6:160589086
# 2    downstream_transcript_variant,intron_variant,g...  20  20:45957384
# 3                                  3_prime_UTR_variant   1  1:109274968
# 4                                                       13  13:22297307
# ..                                                 ...  ..          ...
# 145                      non_coding_transcript_variant   5   5:56511543
# 146   genic_upstream_transcript_variant,intron_variant   2  2:197301841
# 147                                                     22  22:25507825
# 148                                     intron_variant   3   3:49918603
# 149                                                     14  14:20526739
#
#     global_population allele clinical_significance           acc
# 0                          D           risk-factor  NC_000009.12
# 1                          R                benign  NC_000006.12
# 2                          Y                benign  NC_000020.11
# 3                          K           association  NC_000001.11
# 4                          D                        NC_000013.11
# ..                ...    ...                   ...           ...
# 145                        H                        NC_000005.10
# 146                        V                        NC_000002.12
# 147                        R                        NC_000022.11
# 148                        R                        NC_000003.12
# 149                        W                         NC_000014.9
#
# [147 rows x 11 columns]

# %%
#### Now let's make reorder and rename the columns so they match our RENTREZ template. 
RENTREZ_rename = filtered_final_df.rename(columns={'genes': 'Gene ID (GENE_ID)', 'snp_id': 'dbSNP ID (RS)'})
